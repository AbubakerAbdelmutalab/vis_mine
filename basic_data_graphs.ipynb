# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# %%
data = pd.read_csv('logs/processing_geo_fix.csv')

# %%
data['type'].value_counts().plot(kind='bar',title='Event Frequencies')

# %%
s = data['country'].value_counts().plot(kind='bar')

# %%
value_counts = data['country'].value_counts()
data.replace(value_counts[value_counts <= 10].index, np.nan, inplace=True)

# %%
s = data['country'].value_counts().plot(kind='bar',title='Country Frequencies (> 10)')
